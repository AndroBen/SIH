# %%
# !pip install tensorflow tensorflow-gpu opencv-python mediapipe sklearn matplotlib
# Out:
# Requirement already satisfied: tensorflow in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (2.7.0)
# Requirement already satisfied: tensorflow-gpu in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (2.7.0)
# Requirement already satisfied: opencv-python in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (4.5.3.56)
# Collecting mediapipe
#   Using cached mediapipe-0.8.9.1-cp39-cp39-win_amd64.whl (48.5 MB)
# Collecting sklearn
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: matplotlib in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (3.4.2)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.21.0 in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (0.22.0)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (0.36.2)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=9.0.1 in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (12.0.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: tensorflow-estimator<2.8,~=2.7.0rc0 in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (2.7.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (1.34.1)
# Requirement already satisfied: tensorboard~=2.6 in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (2.7.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (1.19.5)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: absl-py>=0.4.0 in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (0.12.0)
# Requirement already satisfied: keras<2.8,>=2.7.0rc0 in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (2.7.0)
# Requirement already satisfied: gast<0.5.0,>=0.2.1 in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (3.7.4.3)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (3.17.3)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (1.12)
# Collecting opencv-contrib-python
#   Downloading opencv_contrib_python-4.5.5.62-cp36-abi3-win_amd64.whl (42.2 MB)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (from mediapipe) (20.3.0)
# Requirement already satisfied: scikit-learn in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (from sklearn) (0.24.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (2.8.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (8.3.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow) (2.0.1)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow) (56.0.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow) (3.3.4)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow) (0.4.5)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow) (2.25.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow) (1.8.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (from tensorboard~=2.6->tensorflow) (1.34.0)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\andro\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\andro\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\andro\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\andro\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\andro\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\andro\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\andro\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\andro\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\andro\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Users\andro\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (from scikit-learn->sklearn) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (from scikit-learn->sklearn) (1.0.0)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (from scikit-learn->sklearn) (1.6.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (1.3.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (1.26.3)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2.10)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\andro\appdata\local\programs\python\python39\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (3.1.1)
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py): started
#   Building wheel for sklearn (setup.py): finished with status 'done'
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1316 sha256=8e0e518d8de7cd2e5f0fe374d89142f2fdd8606d6178c50120054bdd3bf9cf5e
#   Stored in directory: c:\users\andro\appdata\local\pip\cache\wheels\e4\7b\98\b6466d71b8d738a0c547008b9eb39bf8676d1ff6ca4b22af1c
# Successfully built sklearn
# Installing collected packages: opencv-contrib-python, sklearn, mediapipe
# Successfully installed mediapipe-0.8.9.1 opencv-contrib-python-4.5.5.62 sklearn-0.0

# %%
import cv2 
import numpy as np
from matplotlib import pyplot as pt
import time
import os
import mediapipe as mp

# %%
mp_holistic=mp.solutions.holistic
mp_drawing=mp.solutions.drawing_utils

# %%
def mediapipe_detection(image,model):
    image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)#Blue green red to red green blue transformation
    image.flags.writeable=False
    results=model.process(image)
    image.flags.writeable=False
    image=cv2.cvtColor(image,cv2.COLOR_RGB2BGR)
    return image,results

# %%
def draw_landmark(image,results):
    mp_drawing.draw_landmarks(image,results.face_landmarks,mp_holistic.FACEMESH_CONTOURS)
    mp_drawing.draw_landmarks(image,results.pose_landmarks,mp_holistic.POSE_CONNECTIONS)
    mp_drawing.draw_landmarks(image,results.left_hand_landmarks,mp_holistic.HAND_CONNECTIONS)
    mp_drawing.draw_landmarks(image,results.right_hand_landmarks,mp_holistic.HAND_CONNECTIONS)

# %%
def draw_styled_landmark(image,results):
    mp_drawing.draw_landmarks(image,results.face_landmarks,mp_holistic.FACEMESH_CONTOURS,mp_drawing.DrawingSpec(color=(180,110,10),thickness=1,circle_radius=1),mp_drawing.DrawingSpec(color=(80,256,125),thickness=1,circle_radius=1))
    mp_drawing.draw_landmarks(image,results.pose_landmarks,mp_holistic.POSE_CONNECTIONS,mp_drawing.DrawingSpec(color=(80,110,10),thickness=1,circle_radius=4),mp_drawing.DrawingSpec(color=(80,256,125),thickness=1,circle_radius=2))
    mp_drawing.draw_landmarks(image,results.left_hand_landmarks,mp_holistic.HAND_CONNECTIONS,mp_drawing.DrawingSpec(color=(80,110,10),thickness=2,circle_radius=4),mp_drawing.DrawingSpec(color=(80,256,125),thickness=1,circle_radius=2))
    mp_drawing.draw_landmarks(image,results.right_hand_landmarks,mp_holistic.HAND_CONNECTIONS,mp_drawing.DrawingSpec(color=(80,110,10),thickness=2,circle_radius=4),mp_drawing.DrawingSpec(color=(80,256,125),thickness=1,circle_radius=2))

# %%
len(result.face_landmarks.landmark)
# Out:
# 468

# %%
draw_styled_landmark(image,result)

# %%
pt.imshow(cv2.cvtColor(image,cv2.COLOR_BGR2RGB))

# %%
cap.release()
cv2.destroyAllWindows()

# %%
def extract_keypoints(result):
    pose=np.array([[res.x,res.y,res.z,res.visibility] for res in result.pose_landmarks.landmark]).flatten() if result.pose_landmarks else np.zeros(33*4)
    face=np.array([[res.x,res.y,res.z] for res in result.face_landmarks.landmark]).flatten() if result.face_landmarks else np.zeros(468*3)
    lh=np.array([[res.x,res.y,res.z] for res in result.left_hand_landmarks.landmark]).flatten() if result.left_hand_landmarks else np.zeros(21*3)
    rh=np.array([[res.x,res.y,res.z] for res in result.right_hand_landmarks.landmark]).flatten() if result.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose,face,lh,rh])

# %%
extract_keypoints(result).shape
# Out:
# (1662,)

# %%
#PATH FOR DATA
DATA_PATH=os.path.join('MP_DATA')

actions=np.array(['hello','thanks','iloveyou'])
no_sequences=30 #each action has 30 video
sequence_length=30 #each video has 30 frames

# %%
for action in actions:
    for sequence in range(no_sequences):
        try:
            os.makedirs(os.path.join(DATA_PATH,action,str(sequence)))
        except:
            pass

# %%
cap=cv2.VideoCapture(0)
with mp_holistic.Holistic(min_detection_confidence=0.5,min_tracking_confidence=0.5) as holistic:
    for action in actions:
        for sequence in range(no_sequences):
            for frame_num in range(sequence_length):
                
                ret,frame=cap.read()
                image,result=mediapipe_detection(frame,holistic)
                print(result)
                draw_styled_landmark(image,result)
                if frame_num==0:
                    cv2.putText(image,'STARTING COLLECTION',(120,200),cv2.FONT_HERSHEY_SIMPLEX,1,(0,255,0),4,cv2.LINE_AA)
                    cv2.putText(image,'Collecting frame for {} Vide Number {}'.format(action,sequence),(15,12),cv2.FONT_HERSHEY_SIMPLEX,0.5,(0,0,255),1,cv2.LINE_AA)
                    cv2.waitKey(2000)
                else:
                    cv2.putText(image,'Collecting frame for {} Vide Number {}'.format(action,sequence),(15,12),cv2.FONT_HERSHEY_SIMPLEX,0.5,(0,0,255),1,cv2.LINE_AA)
                keypoints=extract_keypoints(result)
                npy_path=os.path.join(DATA_PATH,action,str(sequence),str(frame_num))
                np.save(npy_path,keypoints)
                cv2.imshow('Opencv feed',image)

                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ...
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map={label:num for num,label in enumerate(actions)}

# %%
label_map
# Out:
# {'hello': 0, 'thanks': 1, 'iloveyou': 2}

# %%
labels,sequences=[],[] #sequences-X & labels-Y
for action in actions:
    for sequence in range(no_sequences):
        window=[]
        for frame_num in range(sequence_length):
            npy_path=os.path.join(DATA_PATH,action,str(sequence),"{}.npy".format(frame_num))
            res=np.load(npy_path)
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
x=np.array(sequences)
y=to_categorical(labels).astype(int) #one-hot encoding

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.05)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
import pyttsx3

# %%
engine=pyttsx3.init()

# %%
log_dir=os.path.join("Logs")
tb_callback=TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,1662)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
model.compile(optimizer='Adam',loss='categorical_crossentropy',metrics=['categorical_accuracy'])

# %%
model.fit(x_train,y_train,epochs=350,callbacks=[tb_callback])
# Out:
# Epoch 1/350
# 3/3 [==============================] - 9s 788ms/step - loss: 1.1182 - categorical_accuracy: 0.3294
# Epoch 2/350
# 3/3 [==============================] - 2s 741ms/step - loss: 1.3256 - categorical_accuracy: 0.3529
# Epoch 3/350
# 3/3 [==============================] - 2s 793ms/step - loss: 1.0947 - categorical_accuracy: 0.3294
# Epoch 4/350
# 3/3 [==============================] - 2s 797ms/step - loss: 2.9126 - categorical_accuracy: 0.3647
# Epoch 5/350
# 3/3 [==============================] - 2s 793ms/step - loss: 1.1926 - categorical_accuracy: 0.3294
# Epoch 6/350
# 3/3 [==============================] - 2s 830ms/step - loss: 1.0598 - categorical_accuracy: 0.4000
# Epoch 7/350
# 3/3 [==============================] - 2s 751ms/step - loss: 2.7307 - categorical_accuracy: 0.3412
# Epoch 8/350
# 3/3 [==============================] - 2s 794ms/step - loss: 1.3194 - categorical_accuracy: 0.4118
# Epoch 9/350
# 3/3 [==============================] - 2s 822ms/step - loss: 1.5295 - categorical_accuracy: 0.2941
# Epoch 10/350
# 3/3 [==============================] - 2s 840ms/step - loss: 1.3400 - categorical_accuracy: 0.3176
# Epoch 11/350
# 3/3 [==============================] - 2s 790ms/step - loss: 1.1382 - categorical_accuracy: 0.4000
# Epoch 12/350
# 3/3 [==============================] - 2s 766ms/step - loss: 1.1111 - categorical_accuracy: 0.3529
# Epoch 13/350
# 3/3 [==============================] - 2s 743ms/step - loss: 1.0556 - categorical_accuracy: 0.3647
# Epoch 14/350
# 3/3 [==============================] - 2s 733ms/step - loss: 0.9967 - categorical_accuracy: 0.6235
# Epoch 15/350
# 3/3 [==============================] - 2s 757ms/step - loss: 0.9161 - categorical_accuracy: 0.6235
# Epoch 16/350
# 3/3 [==============================] - 2s 745ms/step - loss: 0.7732 - categorical_accuracy: 0.6118
# Epoch 17/350
# 3/3 [==============================] - 2s 763ms/step - loss: 0.6306 - categorical_accuracy: 0.6000
# Epoch 18/350
# 3/3 [==============================] - 3s 846ms/step - loss: 1.4617 - categorical_accuracy: 0.3647
# Epoch 19/350
# 3/3 [==============================] - 2s 756ms/step - loss: 2.5268 - categorical_accuracy: 0.4000
# Epoch 20/350
# 3/3 [==============================] - 2s 787ms/step - loss: 1.6329 - categorical_accuracy: 0.4118
# Epoch 21/350
# 3/3 [==============================] - 2s 769ms/step - loss: 3.8067 - categorical_accuracy: 0.3412
# Epoch 22/350
# 3/3 [==============================] - 2s 776ms/step - loss: 9.1690 - categorical_accuracy: 0.3529
# Epoch 23/350
# 3/3 [==============================] - 2s 766ms/step - loss: 4.5917 - categorical_accuracy: 0.3647
# Epoch 24/350
# 3/3 [==============================] - 2s 752ms/step - loss: 5.4502 - categorical_accuracy: 0.3176
# Epoch 25/350
# 3/3 [==============================] - 2s 848ms/step - loss: 1.6515 - categorical_accuracy: 0.3294
# Epoch 26/350
# 3/3 [==============================] - 2s 749ms/step - loss: 1.3542 - categorical_accuracy: 0.1647
# Epoch 27/350
# 3/3 [==============================] - 2s 773ms/step - loss: 1.0858 - categorical_accuracy: 0.2471
# Epoch 28/350
# 3/3 [==============================] - 2s 790ms/step - loss: 1.1154 - categorical_accuracy: 0.2824
# Epoch 29/350
# 3/3 [==============================] - 2s 809ms/step - loss: 1.1016 - categorical_accuracy: 0.3294
# Epoch 30/350
# 3/3 [==============================] - 2s 752ms/step - loss: 1.0764 - categorical_accuracy: 0.2706
# Epoch 31/350
# 3/3 [==============================] - 2s 797ms/step - loss: 1.0507 - categorical_accuracy: 0.4235
# Epoch 32/350
# 3/3 [==============================] - 2s 796ms/step - loss: 1.0026 - categorical_accuracy: 0.5765
# Epoch 33/350
# 3/3 [==============================] - 2s 756ms/step - loss: 0.9406 - categorical_accuracy: 0.6118
# Epoch 34/350
# 3/3 [==============================] - 2s 756ms/step - loss: 0.8876 - categorical_accuracy: 0.6000
# Epoch 35/350
# 3/3 [==============================] - 2s 776ms/step - loss: 0.7739 - categorical_accuracy: 0.7176
# Epoch 36/350
# 3/3 [==============================] - 2s 826ms/step - loss: 0.6800 - categorical_accuracy: 0.6941
# Epoch 37/350
# 3/3 [==============================] - 2s 801ms/step - loss: 0.5957 - categorical_accuracy: 0.6824
# Epoch 38/350
# 3/3 [==============================] - 2s 791ms/step - loss: 0.7427 - categorical_accuracy: 0.6118
# Epoch 39/350
# 3/3 [==============================] - 2s 756ms/step - loss: 0.7777 - categorical_accuracy: 0.6235
# Epoch 40/350
# 3/3 [==============================] - 2s 831ms/step - loss: 0.8355 - categorical_accuracy: 0.5529
# Epoch 41/350
# 3/3 [==============================] - 2s 799ms/step - loss: 0.7080 - categorical_accuracy: 0.7294
# Epoch 42/350
# 3/3 [==============================] - 2s 775ms/step - loss: 0.6787 - categorical_accuracy: 0.7176
# Epoch 43/350
# 3/3 [==============================] - 2s 791ms/step - loss: 0.6409 - categorical_accuracy: 0.7059
# Epoch 44/350
# 3/3 [==============================] - 2s 794ms/step - loss: 0.6396 - categorical_accuracy: 0.6824
# Epoch 45/350
# 3/3 [==============================] - 2s 748ms/step - loss: 0.5964 - categorical_accuracy: 0.7059
# Epoch 46/350
# 3/3 [==============================] - 2s 769ms/step - loss: 0.5368 - categorical_accuracy: 0.8000
# Epoch 47/350
# 3/3 [==============================] - 2s 748ms/step - loss: 0.4917 - categorical_accuracy: 0.7882
# Epoch 48/350
# 3/3 [==============================] - 2s 742ms/step - loss: 0.4699 - categorical_accuracy: 0.6706
# Epoch 49/350
# 3/3 [==============================] - 2s 790ms/step - loss: 0.5223 - categorical_accuracy: 0.6588
# Epoch 50/350
# 3/3 [==============================] - 2s 747ms/step - loss: 0.4638 - categorical_accuracy: 0.7176
# Epoch 51/350
# 3/3 [==============================] - 2s 760ms/step - loss: 0.5293 - categorical_accuracy: 0.6824
# Epoch 52/350
# 3/3 [==============================] - 2s 762ms/step - loss: 0.5412 - categorical_accuracy: 0.6824
# Epoch 53/350
# 3/3 [==============================] - 2s 752ms/step - loss: 0.4627 - categorical_accuracy: 0.7529
# Epoch 54/350
# 3/3 [==============================] - 2s 790ms/step - loss: 0.4566 - categorical_accuracy: 0.7294
# Epoch 55/350
# 3/3 [==============================] - 2s 755ms/step - loss: 0.4658 - categorical_accuracy: 0.7647
# Epoch 56/350
# 3/3 [==============================] - 2s 740ms/step - loss: 0.4340 - categorical_accuracy: 0.8118
# Epoch 57/350
# 3/3 [==============================] - 2s 748ms/step - loss: 0.4468 - categorical_accuracy: 0.7412
# Epoch 58/350
# 3/3 [==============================] - 2s 814ms/step - loss: 0.4753 - categorical_accuracy: 0.6941
# Epoch 59/350
# 3/3 [==============================] - 2s 742ms/step - loss: 0.4543 - categorical_accuracy: 0.7529
# Epoch 60/350
# 3/3 [==============================] - 2s 770ms/step - loss: 0.4252 - categorical_accuracy: 0.7765
# Epoch 61/350
# 3/3 [==============================] - 2s 791ms/step - loss: 0.4141 - categorical_accuracy: 0.7647
# Epoch 62/350
# 3/3 [==============================] - 2s 791ms/step - loss: 0.3906 - categorical_accuracy: 0.7882
# Epoch 63/350
# 3/3 [==============================] - 2s 741ms/step - loss: 0.3500 - categorical_accuracy: 0.8588
# Epoch 64/350
# 3/3 [==============================] - 2s 792ms/step - loss: 0.3363 - categorical_accuracy: 0.8706
# Epoch 65/350
# 3/3 [==============================] - 2s 746ms/step - loss: 0.3254 - categorical_accuracy: 0.9176
# Epoch 66/350
# 3/3 [==============================] - 2s 754ms/step - loss: 0.4725 - categorical_accuracy: 0.6706
# Epoch 67/350
# 3/3 [==============================] - 2s 816ms/step - loss: 0.4781 - categorical_accuracy: 0.7176
# Epoch 68/350
# 3/3 [==============================] - 2s 743ms/step - loss: 0.4008 - categorical_accuracy: 0.7882
# Epoch 69/350
# 3/3 [==============================] - 2s 796ms/step - loss: 0.3796 - categorical_accuracy: 0.8706
# Epoch 70/350
# 3/3 [==============================] - 2s 766ms/step - loss: 0.4062 - categorical_accuracy: 0.8824
# Epoch 71/350
# 3/3 [==============================] - 3s 836ms/step - loss: 0.4175 - categorical_accuracy: 0.7294
# Epoch 72/350
# 3/3 [==============================] - 2s 741ms/step - loss: 0.3915 - categorical_accuracy: 0.8471
# Epoch 73/350
# 3/3 [==============================] - 2s 756ms/step - loss: 0.3518 - categorical_accuracy: 0.8353
# Epoch 74/350
# 3/3 [==============================] - 2s 760ms/step - loss: 0.4107 - categorical_accuracy: 0.8118
# Epoch 75/350
# 3/3 [==============================] - 2s 765ms/step - loss: 0.3250 - categorical_accuracy: 0.8353
# Epoch 76/350
# 3/3 [==============================] - 2s 787ms/step - loss: 0.3215 - categorical_accuracy: 0.8706
# Epoch 77/350
# 3/3 [==============================] - 2s 794ms/step - loss: 0.2611 - categorical_accuracy: 0.9059
# Epoch 78/350
# 3/3 [==============================] - 2s 776ms/step - loss: 0.2576 - categorical_accuracy: 0.8941
# Epoch 79/350
# 3/3 [==============================] - 2s 774ms/step - loss: 0.2588 - categorical_accuracy: 0.8824
# Epoch 80/350
# 3/3 [==============================] - 2s 784ms/step - loss: 0.3186 - categorical_accuracy: 0.8588
# Epoch 81/350
# 3/3 [==============================] - 2s 784ms/step - loss: 0.3967 - categorical_accuracy: 0.8588
# Epoch 82/350
# 3/3 [==============================] - 2s 781ms/step - loss: 0.3777 - categorical_accuracy: 0.8235
# Epoch 83/350
# 3/3 [==============================] - 3s 883ms/step - loss: 0.5703 - categorical_accuracy: 0.7294
# Epoch 84/350
# 3/3 [==============================] - 2s 773ms/step - loss: 0.6146 - categorical_accuracy: 0.6706
# Epoch 85/350
# 3/3 [==============================] - 2s 789ms/step - loss: 0.4662 - categorical_accuracy: 0.7647
# Epoch 86/350
# 3/3 [==============================] - 2s 772ms/step - loss: 0.4466 - categorical_accuracy: 0.7765
# Epoch 87/350
# 3/3 [==============================] - 2s 728ms/step - loss: 0.3681 - categorical_accuracy: 0.8118
# Epoch 88/350
# 3/3 [==============================] - 2s 739ms/step - loss: 0.3803 - categorical_accuracy: 0.8000
# Epoch 89/350
# 3/3 [==============================] - 2s 831ms/step - loss: 0.3759 - categorical_accuracy: 0.8824
# Epoch 90/350
# 3/3 [==============================] - 2s 761ms/step - loss: 0.3611 - categorical_accuracy: 0.8353
# Epoch 91/350
# 3/3 [==============================] - 2s 768ms/step - loss: 0.3292 - categorical_accuracy: 0.9412
# Epoch 92/350
# 3/3 [==============================] - 3s 895ms/step - loss: 0.3183 - categorical_accuracy: 0.9412
# Epoch 93/350
# 3/3 [==============================] - 2s 802ms/step - loss: 0.3076 - categorical_accuracy: 0.8941
# Epoch 94/350
# 3/3 [==============================] - 2s 739ms/step - loss: 0.2665 - categorical_accuracy: 0.9294
# Epoch 95/350
# 3/3 [==============================] - 2s 759ms/step - loss: 0.2349 - categorical_accuracy: 0.9647
# Epoch 96/350
# 3/3 [==============================] - 2s 774ms/step - loss: 0.2227 - categorical_accuracy: 0.9412
# Epoch 97/350
# 3/3 [==============================] - 2s 800ms/step - loss: 0.1981 - categorical_accuracy: 0.9529
# Epoch 98/350
# 3/3 [==============================] - 2s 782ms/step - loss: 0.1890 - categorical_accuracy: 0.9765
# Epoch 99/350
# 3/3 [==============================] - 2s 807ms/step - loss: 0.1465 - categorical_accuracy: 0.9765
# Epoch 100/350
# 3/3 [==============================] - 2s 865ms/step - loss: 0.1920 - categorical_accuracy: 0.9059
# Epoch 101/350
# 3/3 [==============================] - 2s 874ms/step - loss: 0.1500 - categorical_accuracy: 0.9529
# Epoch 102/350
# 3/3 [==============================] - 3s 883ms/step - loss: 0.1966 - categorical_accuracy: 0.9294
# Epoch 103/350
# 3/3 [==============================] - 3s 960ms/step - loss: 0.1309 - categorical_accuracy: 0.9765
# Epoch 104/350
# 3/3 [==============================] - 2s 800ms/step - loss: 0.2008 - categorical_accuracy: 0.9412
# Epoch 105/350
# 3/3 [==============================] - 3s 818ms/step - loss: 0.2235 - categorical_accuracy: 0.8941
# Epoch 106/350
# 3/3 [==============================] - 2s 764ms/step - loss: 0.2020 - categorical_accuracy: 0.9294
# Epoch 107/350
# 3/3 [==============================] - 2s 755ms/step - loss: 0.1515 - categorical_accuracy: 0.9294
# Epoch 108/350
# 3/3 [==============================] - 2s 754ms/step - loss: 0.1607 - categorical_accuracy: 0.9412
# Epoch 109/350
# 3/3 [==============================] - 2s 745ms/step - loss: 0.2497 - categorical_accuracy: 0.9176
# Epoch 110/350
# 3/3 [==============================] - 2s 774ms/step - loss: 0.3200 - categorical_accuracy: 0.8824
# Epoch 111/350
# 3/3 [==============================] - 2s 799ms/step - loss: 0.1412 - categorical_accuracy: 0.9647
# Epoch 112/350
# 3/3 [==============================] - 2s 780ms/step - loss: 0.1150 - categorical_accuracy: 0.9647
# Epoch 113/350
# 3/3 [==============================] - 2s 783ms/step - loss: 0.1375 - categorical_accuracy: 0.9294
# Epoch 114/350
# 3/3 [==============================] - 2s 766ms/step - loss: 0.2950 - categorical_accuracy: 0.8471
# Epoch 115/350
# 3/3 [==============================] - 2s 755ms/step - loss: 0.2623 - categorical_accuracy: 0.8941
# Epoch 116/350
# 3/3 [==============================] - 3s 843ms/step - loss: 0.2867 - categorical_accuracy: 0.9294
# Epoch 117/350
# 3/3 [==============================] - 2s 815ms/step - loss: 0.3260 - categorical_accuracy: 0.8824
# Epoch 118/350
# 3/3 [==============================] - 2s 737ms/step - loss: 0.2555 - categorical_accuracy: 0.9529
# Epoch 119/350
# 3/3 [==============================] - 2s 794ms/step - loss: 0.2301 - categorical_accuracy: 0.8941
# Epoch 120/350
# 3/3 [==============================] - 2s 785ms/step - loss: 0.2218 - categorical_accuracy: 0.9294
# Epoch 121/350
# 3/3 [==============================] - 2s 732ms/step - loss: 0.3149 - categorical_accuracy: 0.8824
# Epoch 122/350
# 3/3 [==============================] - 2s 780ms/step - loss: 0.4848 - categorical_accuracy: 0.8353
# Epoch 123/350
# 3/3 [==============================] - 2s 820ms/step - loss: 0.3607 - categorical_accuracy: 0.8471
# Epoch 124/350
# 3/3 [==============================] - 2s 789ms/step - loss: 0.4110 - categorical_accuracy: 0.8118
# Epoch 125/350
# 3/3 [==============================] - 2s 737ms/step - loss: 0.3176 - categorical_accuracy: 0.8706
# Epoch 126/350
# 3/3 [==============================] - 2s 779ms/step - loss: 0.2296 - categorical_accuracy: 0.9294
# Epoch 127/350
# 3/3 [==============================] - 2s 757ms/step - loss: 0.2271 - categorical_accuracy: 0.9294
# Epoch 128/350
# 3/3 [==============================] - 2s 770ms/step - loss: 0.2477 - categorical_accuracy: 0.9059
# Epoch 129/350
# 3/3 [==============================] - 2s 755ms/step - loss: 0.1844 - categorical_accuracy: 0.9765
# Epoch 130/350
# 3/3 [==============================] - 2s 733ms/step - loss: 0.2013 - categorical_accuracy: 0.9765
# Epoch 131/350
# 3/3 [==============================] - 2s 756ms/step - loss: 0.1667 - categorical_accuracy: 0.9647
# Epoch 132/350
# 3/3 [==============================] - 2s 799ms/step - loss: 0.1555 - categorical_accuracy: 0.9647
# Epoch 133/350
# 3/3 [==============================] - 2s 778ms/step - loss: 0.1471 - categorical_accuracy: 0.9765
# Epoch 134/350
# 3/3 [==============================] - 2s 802ms/step - loss: 0.1597 - categorical_accuracy: 0.9412
# Epoch 135/350
# 3/3 [==============================] - 2s 798ms/step - loss: 0.1163 - categorical_accuracy: 0.9765
# Epoch 136/350
# 3/3 [==============================] - 2s 778ms/step - loss: 0.1279 - categorical_accuracy: 0.9529
# Epoch 137/350
# 3/3 [==============================] - 2s 788ms/step - loss: 0.1182 - categorical_accuracy: 0.9765
# Epoch 138/350
# 3/3 [==============================] - 2s 730ms/step - loss: 0.1193 - categorical_accuracy: 0.9765
# Epoch 139/350
# 3/3 [==============================] - 2s 779ms/step - loss: 0.0902 - categorical_accuracy: 0.9882
# Epoch 140/350
# 3/3 [==============================] - 2s 804ms/step - loss: 0.0854 - categorical_accuracy: 0.9882
# Epoch 141/350
# 3/3 [==============================] - 2s 756ms/step - loss: 0.0898 - categorical_accuracy: 0.9765
# Epoch 142/350
# 3/3 [==============================] - 2s 765ms/step - loss: 0.1204 - categorical_accuracy: 0.9529
# Epoch 143/350
# 3/3 [==============================] - 2s 747ms/step - loss: 0.1476 - categorical_accuracy: 0.9647
# Epoch 144/350
# 3/3 [==============================] - 2s 755ms/step - loss: 0.0957 - categorical_accuracy: 0.9765
# Epoch 145/350
# 3/3 [==============================] - 2s 751ms/step - loss: 0.0963 - categorical_accuracy: 0.9765
# Epoch 146/350
# 3/3 [==============================] - 2s 788ms/step - loss: 0.0941 - categorical_accuracy: 0.9765
# Epoch 147/350
# 3/3 [==============================] - 2s 792ms/step - loss: 0.0704 - categorical_accuracy: 0.9882
# Epoch 148/350
# 3/3 [==============================] - 2s 755ms/step - loss: 0.0696 - categorical_accuracy: 0.9882
# Epoch 149/350
# 3/3 [==============================] - 2s 777ms/step - loss: 0.1113 - categorical_accuracy: 0.9647
# Epoch 150/350
# 3/3 [==============================] - 2s 747ms/step - loss: 0.0876 - categorical_accuracy: 0.9647
# Epoch 151/350
# 3/3 [==============================] - 2s 775ms/step - loss: 0.2940 - categorical_accuracy: 0.9059
# Epoch 152/350
# 3/3 [==============================] - 2s 776ms/step - loss: 0.4470 - categorical_accuracy: 0.8471
# Epoch 153/350
# 3/3 [==============================] - 2s 789ms/step - loss: 0.1988 - categorical_accuracy: 0.9412
# Epoch 154/350
# 3/3 [==============================] - 2s 732ms/step - loss: 0.2622 - categorical_accuracy: 0.8941
# Epoch 155/350
# 3/3 [==============================] - 2s 745ms/step - loss: 0.3143 - categorical_accuracy: 0.8353
# Epoch 156/350
# 3/3 [==============================] - 2s 805ms/step - loss: 0.1988 - categorical_accuracy: 0.9647
# Epoch 157/350
# 3/3 [==============================] - 2s 795ms/step - loss: 0.1977 - categorical_accuracy: 0.9529
# Epoch 158/350
# 3/3 [==============================] - 2s 840ms/step - loss: 0.1587 - categorical_accuracy: 0.9529
# Epoch 159/350
# 3/3 [==============================] - 2s 812ms/step - loss: 0.1452 - categorical_accuracy: 0.9529
# Epoch 160/350
# 3/3 [==============================] - 2s 761ms/step - loss: 0.1239 - categorical_accuracy: 0.9647
# Epoch 161/350
# 3/3 [==============================] - 2s 799ms/step - loss: 0.1084 - categorical_accuracy: 0.9765
# Epoch 162/350
# 3/3 [==============================] - 2s 739ms/step - loss: 0.1207 - categorical_accuracy: 0.9765
# Epoch 163/350
# 3/3 [==============================] - 2s 744ms/step - loss: 0.1014 - categorical_accuracy: 0.9882
# Epoch 164/350
# 3/3 [==============================] - 2s 760ms/step - loss: 0.1026 - categorical_accuracy: 0.9765
# Epoch 165/350
# 3/3 [==============================] - 2s 753ms/step - loss: 0.0956 - categorical_accuracy: 0.9647
# Epoch 166/350
# 3/3 [==============================] - 2s 755ms/step - loss: 0.1108 - categorical_accuracy: 0.9765
# Epoch 167/350
# 3/3 [==============================] - 2s 766ms/step - loss: 0.1047 - categorical_accuracy: 0.9765
# Epoch 168/350
# 3/3 [==============================] - 2s 724ms/step - loss: 0.1109 - categorical_accuracy: 0.9765
# Epoch 169/350
# 3/3 [==============================] - 2s 802ms/step - loss: 0.0921 - categorical_accuracy: 0.9765
# Epoch 170/350
# 3/3 [==============================] - 2s 763ms/step - loss: 0.0829 - categorical_accuracy: 0.9765
# Epoch 171/350
# 3/3 [==============================] - 2s 787ms/step - loss: 0.0788 - categorical_accuracy: 0.9882
# Epoch 172/350
# 3/3 [==============================] - 2s 814ms/step - loss: 0.0741 - categorical_accuracy: 0.9765
# Epoch 173/350
# 3/3 [==============================] - 2s 753ms/step - loss: 0.0704 - categorical_accuracy: 0.9765
# Epoch 174/350
# 3/3 [==============================] - 2s 840ms/step - loss: 0.0786 - categorical_accuracy: 0.9882
# Epoch 175/350
# 3/3 [==============================] - 2s 778ms/step - loss: 0.1286 - categorical_accuracy: 0.9647
# Epoch 176/350
# 3/3 [==============================] - 2s 785ms/step - loss: 0.1464 - categorical_accuracy: 0.9529
# Epoch 177/350
# 3/3 [==============================] - 2s 773ms/step - loss: 0.1474 - categorical_accuracy: 0.9412
# Epoch 178/350
# 3/3 [==============================] - 2s 791ms/step - loss: 0.1176 - categorical_accuracy: 0.9412
# Epoch 179/350
# 3/3 [==============================] - 2s 778ms/step - loss: 0.1223 - categorical_accuracy: 0.9529
# Epoch 180/350
# 3/3 [==============================] - 2s 768ms/step - loss: 0.0767 - categorical_accuracy: 0.9765
# Epoch 181/350
# 3/3 [==============================] - 2s 787ms/step - loss: 0.0697 - categorical_accuracy: 0.9882
# Epoch 182/350
# 3/3 [==============================] - 2s 787ms/step - loss: 0.0701 - categorical_accuracy: 0.9882
# Epoch 183/350
# 3/3 [==============================] - 2s 794ms/step - loss: 0.0667 - categorical_accuracy: 0.9882
# Epoch 184/350
# 3/3 [==============================] - 2s 783ms/step - loss: 0.0689 - categorical_accuracy: 0.9765
# Epoch 185/350
# 3/3 [==============================] - 2s 764ms/step - loss: 0.0738 - categorical_accuracy: 0.9765
# Epoch 186/350
# 3/3 [==============================] - 2s 802ms/step - loss: 0.0877 - categorical_accuracy: 0.9765
# Epoch 187/350
# 3/3 [==============================] - 2s 799ms/step - loss: 0.0632 - categorical_accuracy: 0.9765
# Epoch 188/350
# 3/3 [==============================] - 2s 779ms/step - loss: 0.0557 - categorical_accuracy: 0.9882
# Epoch 189/350
# 3/3 [==============================] - 2s 760ms/step - loss: 0.0633 - categorical_accuracy: 0.9765
# Epoch 190/350
# 3/3 [==============================] - 2s 751ms/step - loss: 0.0519 - categorical_accuracy: 0.9882
# Epoch 191/350
# 3/3 [==============================] - 2s 831ms/step - loss: 0.0594 - categorical_accuracy: 0.9882
# Epoch 192/350
# 3/3 [==============================] - 2s 786ms/step - loss: 0.0601 - categorical_accuracy: 0.9882
# Epoch 193/350
# 3/3 [==============================] - 2s 830ms/step - loss: 0.0510 - categorical_accuracy: 0.9882
# Epoch 194/350
# 3/3 [==============================] - 2s 784ms/step - loss: 0.0500 - categorical_accuracy: 0.9882
# Epoch 195/350
# 3/3 [==============================] - 2s 782ms/step - loss: 1.5045 - categorical_accuracy: 0.6824
# Epoch 196/350
# 3/3 [==============================] - 2s 786ms/step - loss: 0.6727 - categorical_accuracy: 0.6588
# Epoch 197/350
# 3/3 [==============================] - 2s 798ms/step - loss: 0.5346 - categorical_accuracy: 0.7882
# Epoch 198/350
# 3/3 [==============================] - 2s 775ms/step - loss: 0.5540 - categorical_accuracy: 0.6941
# Epoch 199/350
# 3/3 [==============================] - 2s 760ms/step - loss: 0.4117 - categorical_accuracy: 0.8235
# Epoch 200/350
# 3/3 [==============================] - 2s 798ms/step - loss: 0.3060 - categorical_accuracy: 0.8824
# Epoch 201/350
# 3/3 [==============================] - 2s 770ms/step - loss: 0.2579 - categorical_accuracy: 0.8941
# Epoch 202/350
# 3/3 [==============================] - 2s 773ms/step - loss: 0.1907 - categorical_accuracy: 0.9647
# Epoch 203/350
# 3/3 [==============================] - 2s 761ms/step - loss: 0.1512 - categorical_accuracy: 0.9647
# Epoch 204/350
# 3/3 [==============================] - 2s 843ms/step - loss: 0.1212 - categorical_accuracy: 0.9765
# Epoch 205/350
# 3/3 [==============================] - 2s 757ms/step - loss: 0.1112 - categorical_accuracy: 0.9765
# Epoch 206/350
# 3/3 [==============================] - 2s 757ms/step - loss: 0.0975 - categorical_accuracy: 0.9765
# Epoch 207/350
# 3/3 [==============================] - 2s 841ms/step - loss: 0.0892 - categorical_accuracy: 0.9765
# Epoch 208/350
# 3/3 [==============================] - 3s 838ms/step - loss: 0.1091 - categorical_accuracy: 0.9765
# Epoch 209/350
# 3/3 [==============================] - 2s 776ms/step - loss: 0.0989 - categorical_accuracy: 0.9647
# Epoch 210/350
# 3/3 [==============================] - 2s 806ms/step - loss: 0.0985 - categorical_accuracy: 0.9765
# Epoch 211/350
# 3/3 [==============================] - 2s 821ms/step - loss: 0.1088 - categorical_accuracy: 0.9647
# Epoch 212/350
# 3/3 [==============================] - 3s 777ms/step - loss: 0.1122 - categorical_accuracy: 0.9647
# Epoch 213/350
# 3/3 [==============================] - 2s 746ms/step - loss: 0.1636 - categorical_accuracy: 0.9294
# Epoch 214/350
# 3/3 [==============================] - 2s 740ms/step - loss: 0.2444 - categorical_accuracy: 0.9176
# Epoch 215/350
# 3/3 [==============================] - 2s 792ms/step - loss: 0.1878 - categorical_accuracy: 0.9059
# Epoch 216/350
# 3/3 [==============================] - 2s 772ms/step - loss: 0.0900 - categorical_accuracy: 0.9765
# Epoch 217/350
# 3/3 [==============================] - 2s 751ms/step - loss: 0.1562 - categorical_accuracy: 0.9647
# Epoch 218/350
# 3/3 [==============================] - 2s 750ms/step - loss: 0.2193 - categorical_accuracy: 0.9059
# Epoch 219/350
# 3/3 [==============================] - 2s 792ms/step - loss: 0.1223 - categorical_accuracy: 0.9765
# Epoch 220/350
# 3/3 [==============================] - 2s 818ms/step - loss: 0.1403 - categorical_accuracy: 0.9529
# Epoch 221/350
# 3/3 [==============================] - 2s 746ms/step - loss: 0.1032 - categorical_accuracy: 0.9765
# Epoch 222/350
# 3/3 [==============================] - 2s 819ms/step - loss: 0.1161 - categorical_accuracy: 0.9529
# Epoch 223/350
# 3/3 [==============================] - 2s 797ms/step - loss: 0.0867 - categorical_accuracy: 0.9765
# Epoch 224/350
# 3/3 [==============================] - 2s 769ms/step - loss: 0.0853 - categorical_accuracy: 0.9765
# Epoch 225/350
# 3/3 [==============================] - 2s 778ms/step - loss: 0.1054 - categorical_accuracy: 0.9647
# Epoch 226/350
# 3/3 [==============================] - 2s 762ms/step - loss: 0.1375 - categorical_accuracy: 0.9412
# Epoch 227/350
# 3/3 [==============================] - 2s 769ms/step - loss: 0.0900 - categorical_accuracy: 0.9765
# Epoch 228/350
# 3/3 [==============================] - 3s 848ms/step - loss: 0.1824 - categorical_accuracy: 0.9176
# Epoch 229/350
# 3/3 [==============================] - 2s 751ms/step - loss: 0.1676 - categorical_accuracy: 0.9529
# Epoch 230/350
# 3/3 [==============================] - 2s 804ms/step - loss: 0.2072 - categorical_accuracy: 0.9059
# Epoch 231/350
# 3/3 [==============================] - 2s 785ms/step - loss: 0.3456 - categorical_accuracy: 0.8824
# Epoch 232/350
# 3/3 [==============================] - 2s 852ms/step - loss: 0.1343 - categorical_accuracy: 0.9529
# Epoch 233/350
# 3/3 [==============================] - 2s 812ms/step - loss: 0.1593 - categorical_accuracy: 0.9412
# Epoch 234/350
# 3/3 [==============================] - 2s 740ms/step - loss: 0.2420 - categorical_accuracy: 0.8941
# Epoch 235/350
# 3/3 [==============================] - 2s 776ms/step - loss: 0.1020 - categorical_accuracy: 0.9647
# Epoch 236/350
# 3/3 [==============================] - 2s 723ms/step - loss: 0.1337 - categorical_accuracy: 0.9647
# Epoch 237/350
# 3/3 [==============================] - 2s 740ms/step - loss: 0.1251 - categorical_accuracy: 0.9529
# Epoch 238/350
# 3/3 [==============================] - 2s 756ms/step - loss: 0.1791 - categorical_accuracy: 0.9412
# Epoch 239/350
# 3/3 [==============================] - 2s 784ms/step - loss: 0.0985 - categorical_accuracy: 0.9647
# Epoch 240/350
# 3/3 [==============================] - 2s 767ms/step - loss: 0.1233 - categorical_accuracy: 0.9529
# Epoch 241/350
# 3/3 [==============================] - 2s 739ms/step - loss: 0.1666 - categorical_accuracy: 0.9294
# Epoch 242/350
# 3/3 [==============================] - 2s 757ms/step - loss: 0.1242 - categorical_accuracy: 0.9412
# Epoch 243/350
# 3/3 [==============================] - 2s 750ms/step - loss: 0.3555 - categorical_accuracy: 0.9059
# Epoch 244/350
# 3/3 [==============================] - 2s 826ms/step - loss: 0.1890 - categorical_accuracy: 0.9294
# Epoch 245/350
# 3/3 [==============================] - 2s 750ms/step - loss: 0.0898 - categorical_accuracy: 0.9765
# Epoch 246/350
# 3/3 [==============================] - 2s 830ms/step - loss: 0.0895 - categorical_accuracy: 0.9882
# Epoch 247/350
# 3/3 [==============================] - 2s 789ms/step - loss: 0.0862 - categorical_accuracy: 0.9882
# Epoch 248/350
# 3/3 [==============================] - 2s 780ms/step - loss: 0.0907 - categorical_accuracy: 0.9882
# Epoch 249/350
# 3/3 [==============================] - 2s 746ms/step - loss: 0.0800 - categorical_accuracy: 0.9882
# Epoch 250/350
# 3/3 [==============================] - 2s 756ms/step - loss: 0.0825 - categorical_accuracy: 0.9765
# Epoch 251/350
# 3/3 [==============================] - 2s 789ms/step - loss: 0.0754 - categorical_accuracy: 0.9882
# Epoch 252/350
# 3/3 [==============================] - 2s 800ms/step - loss: 0.0784 - categorical_accuracy: 0.9882
# Epoch 253/350
# 3/3 [==============================] - 2s 741ms/step - loss: 0.0719 - categorical_accuracy: 0.9882
# Epoch 254/350
# 3/3 [==============================] - 2s 777ms/step - loss: 0.0676 - categorical_accuracy: 0.9882
# Epoch 255/350
# 3/3 [==============================] - 2s 751ms/step - loss: 0.0671 - categorical_accuracy: 0.9882
# Epoch 256/350
# 3/3 [==============================] - 2s 797ms/step - loss: 0.0608 - categorical_accuracy: 0.9882
# Epoch 257/350
# 3/3 [==============================] - 2s 773ms/step - loss: 0.0598 - categorical_accuracy: 0.9882
# Epoch 258/350
# 3/3 [==============================] - 2s 752ms/step - loss: 0.0580 - categorical_accuracy: 0.9882
# Epoch 259/350
# 3/3 [==============================] - 3s 837ms/step - loss: 0.0564 - categorical_accuracy: 0.9882
# Epoch 260/350
# 3/3 [==============================] - 2s 792ms/step - loss: 0.0504 - categorical_accuracy: 0.9882
# Epoch 261/350
# 3/3 [==============================] - 2s 781ms/step - loss: 0.0669 - categorical_accuracy: 0.9765
# Epoch 262/350
# 3/3 [==============================] - 2s 757ms/step - loss: 0.0544 - categorical_accuracy: 0.9882
# Epoch 263/350
# 3/3 [==============================] - 2s 754ms/step - loss: 0.0493 - categorical_accuracy: 0.9882
# Epoch 264/350
# 3/3 [==============================] - 2s 774ms/step - loss: 0.0461 - categorical_accuracy: 0.9882
# Epoch 265/350
# 3/3 [==============================] - 2s 751ms/step - loss: 0.0647 - categorical_accuracy: 0.9765
# Epoch 266/350
# 3/3 [==============================] - 2s 755ms/step - loss: 0.1984 - categorical_accuracy: 0.9294
# Epoch 267/350
# 3/3 [==============================] - 2s 783ms/step - loss: 0.1407 - categorical_accuracy: 0.9529
# Epoch 268/350
# 3/3 [==============================] - 2s 750ms/step - loss: 0.1880 - categorical_accuracy: 0.9294
# Epoch 269/350
# 3/3 [==============================] - 2s 795ms/step - loss: 0.2320 - categorical_accuracy: 0.8824
# Epoch 270/350
# 3/3 [==============================] - 2s 744ms/step - loss: 0.2487 - categorical_accuracy: 0.8941
# Epoch 271/350
# 3/3 [==============================] - 2s 761ms/step - loss: 0.1320 - categorical_accuracy: 0.9529
# Epoch 272/350
# 3/3 [==============================] - 2s 755ms/step - loss: 0.1154 - categorical_accuracy: 0.9765
# Epoch 273/350
# 3/3 [==============================] - 2s 741ms/step - loss: 0.1166 - categorical_accuracy: 0.9647
# Epoch 274/350
# 3/3 [==============================] - 2s 755ms/step - loss: 0.0902 - categorical_accuracy: 0.9765
# Epoch 275/350
# 3/3 [==============================] - 2s 792ms/step - loss: 0.0872 - categorical_accuracy: 0.9765
# Epoch 276/350
# 3/3 [==============================] - 2s 768ms/step - loss: 0.0716 - categorical_accuracy: 0.9882
# Epoch 277/350
# 3/3 [==============================] - 2s 813ms/step - loss: 0.0699 - categorical_accuracy: 0.9882
# Epoch 278/350
# 3/3 [==============================] - 2s 758ms/step - loss: 0.0656 - categorical_accuracy: 0.9882
# Epoch 279/350
# 3/3 [==============================] - 2s 823ms/step - loss: 0.0609 - categorical_accuracy: 0.9882
# Epoch 280/350
# 3/3 [==============================] - 2s 745ms/step - loss: 0.0589 - categorical_accuracy: 0.9882
# Epoch 281/350
# 3/3 [==============================] - 2s 740ms/step - loss: 0.0563 - categorical_accuracy: 0.9882
# Epoch 282/350
# 3/3 [==============================] - 2s 779ms/step - loss: 0.0534 - categorical_accuracy: 0.9882
# Epoch 283/350
# 3/3 [==============================] - 2s 813ms/step - loss: 0.0534 - categorical_accuracy: 0.9882
# Epoch 284/350
# 3/3 [==============================] - 2s 754ms/step - loss: 0.0515 - categorical_accuracy: 0.9882
# Epoch 285/350
# 3/3 [==============================] - 2s 796ms/step - loss: 0.0491 - categorical_accuracy: 0.9882
# Epoch 286/350
# 3/3 [==============================] - 2s 766ms/step - loss: 0.0477 - categorical_accuracy: 0.9882
# Epoch 287/350
# 3/3 [==============================] - 2s 765ms/step - loss: 0.0467 - categorical_accuracy: 0.9882
# Epoch 288/350
# 3/3 [==============================] - 2s 736ms/step - loss: 0.0460 - categorical_accuracy: 0.9882
# Epoch 289/350
# 3/3 [==============================] - 3s 882ms/step - loss: 0.0448 - categorical_accuracy: 0.9882
# Epoch 290/350
# 3/3 [==============================] - 3s 891ms/step - loss: 0.0446 - categorical_accuracy: 0.9882
# Epoch 291/350
# 3/3 [==============================] - 2s 776ms/step - loss: 0.0433 - categorical_accuracy: 0.9882
# Epoch 292/350
# 3/3 [==============================] - 2s 780ms/step - loss: 0.0426 - categorical_accuracy: 0.9882
# Epoch 293/350
# 2/3 [===================>..........] - ETA: 0s - loss: 0.0513 - categorical_accuracy: 0.9844
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-108-502c08890987> in <module>
# ----> 1 model.fit(x_train,y_train,epochs=350,callbacks=[tb_callback])
#
# c:\users\andro\appdata\local\programs\python\python39\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# c:\users\andro\appdata\local\programs\python\python39\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1214                 _r=1):
#    1215               callbacks.on_train_batch_begin(step)
# -> 1216               tmp_logs = self.train_function(iterator)
#    1217               if data_handler.should_sync:
#    1218                 context.async_wait()
#
# c:\users\andro\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# c:\users\andro\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     908
#     909       with OptionalXlaContext(self._jit_compile):
# --> 910         result = self._call(*args, **kwds)
#     911
#     912       new_tracing_count = self.experimental_get_tracing_count()
#
# c:\users\andro\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     940       # In this case we have created variables on the first call, so we run the
#     941       # defunned version which is guaranteed to never create variables.
# --> 942       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     943     elif self._stateful_fn is not None:
#     944       # Release the lock early so that multiple threads can perform the call
#
# c:\users\andro\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    3128       (graph_function,
#    3129        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3130     return graph_function._call_flat(
#    3131         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3132
#
# c:\users\andro\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1957         and executing_eagerly):
#    1958       # No tape is watching; skip to running the function.
# -> 1959       return self._build_call_outputs(self._inference_function.call(
#    1960           ctx, args, cancellation_manager=cancellation_manager))
#    1961     forward_backward = self._select_forward_and_backward_functions(
#
# c:\users\andro\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     596       with _InterpolateFunctionError(self):
#     597         if cancellation_manager is None:
# --> 598           outputs = execute.execute(
#     599               str(self.signature.name),
#     600               num_outputs=self._num_outputs,
#
# c:\users\andro\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      56   try:
#      57     ctx.ensure_initialized()
# ---> 58     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      59                                         inputs, attrs, num_outputs)
#      60   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
model.evaluate(x_test,y_test)
# Out:
# 1/1 [==============================] - 1s 1s/step - loss: 3.4359 - categorical_accuracy: 0.8000
# [3.43589448928833, 0.800000011920929]

# %%
predict=model.predict(x_test)
actions[np.argmax(predict[1])]
# Out:
# 'hello'

# %%
actions[np.argmax(y_test[1])]
# Out:
# 'hello'

# %%
model.save("sign.h5")

# %%
model.load_weights('sign.h5')

# %%
from scipy import stats

# %%
colors = [(245,117,16), (117,245,16), (16,117,245)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
sequence = []
sentence = []
predictions = []
threshold = 0.5

cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        
        # Draw landmarks
        draw_styled_landmark(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-30:]#last 30 frames=1 video
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0] #change dimentsion of sequence from 30,1692=>1,30,1692 to pass only one sequence to predict
            predictions.append(np.argmax(res))
            
            
        #3. Viz logic
            if np.unique(predictions[-10:])[0]==np.argmax(res): 
                if res[np.argmax(res)] > threshold:
                    
                    if len(sentence) > 0: 
                        if actions[np.argmax(res)] != sentence[-1]:
                            sentence.append(actions[np.argmax(res)])
                            engine.say(sentence[-1])
                            engine.runAndWait()
                    else:
                        sentence.append(actions[np.argmax(res)])
                        engine.say(sentence[-1])
                        engine.runAndWait()
                    

            if len(sentence) > 5: 
                sentence = sentence[-5:]
        # Viz probabilities
            image = prob_viz(res, actions, image, colors)
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()

# %%
# Out:
# 2

# %%
cap.release()
cv2.destroyAllWindows()
